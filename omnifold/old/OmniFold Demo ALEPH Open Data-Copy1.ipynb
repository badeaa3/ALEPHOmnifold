# %% [markdown]
# # OmniFold with ALEPH Open Data

# %% [markdown]
# ### Imports

# %%
import os

import tensorflow as tf
tf.compat.v1.disable_eager_execution()

import energyflow as ef
import energyflow.archs
import matplotlib.pyplot as plt
import numpy as np
import uproot

import omnifold
import modplot
import ibu

# %% [markdown]
# ### Plot Style

# %%
#plt.rcParams['figure.figsize'] = (4,4)
#plt.rcParams['figure.dpi'] = 120
#plt.rcParams['font.family'] = 'serif'
#plt.rcParams['text.usetex'] = True

# %% [markdown]
# ## Loading the Data

# %%
aleph_path = '/callisto/ALEPH'

# load data, currently just get thrust values
thrust_arrs = []
years = [
    #'1992', 
    #'1993', 
    '1994', 
    #'1995'
]
eSels = [
    #'passesNTupleAfterCut',
    #'passesTotalChgEnergyMin', 
    #'passesNTrkMin', 
    #'passesNeuNch',
    #'passesSTheta'
]

for year in years:
    data_file = uproot.open(os.path.join(aleph_path, 'LEP1Data{}_recons_aftercut-MERGED.root'.format(year)))
    event_mask = np.ones(len(data_file['t']['EventNo'])) 
    for eSel in eSels:
        event_mask *= data_file['t'][eSel].array()
    event_mask = np.array(event_mask).astype(bool)
    thrust_arrs.append(1 - data_file['t']['Thrust'].array()[event_mask])
    
# dictionary to hold observable values
nature = {'data_thrusts': np.concatenate(thrust_arrs)}

# load mc, currently just get thrust values
mc_file = uproot.open(os.path.join(aleph_path, 'alephMCRecoAfterCutPaths_1994.root'))
event_mask = np.ones(len(mc_file['t']['EventNo'])) 
for eSel in eSels:
    event_mask *= mc_file['t'][eSel].array()
event_mask = np.array(event_mask).astype(bool)
synthetic = {'gen_thrusts': 1 - mc_file['tgen']['Thrust'].array()[event_mask],
             'genBefore_thrusts': 1 - mc_file['tgenBefore']['Thrust'].array(),
             'sim_thrusts': 1 - mc_file['t']['Thrust'].array()[event_mask]}

# %%
# compute the distributions to determine the bin-by-bin corrections
bins = np.linspace(0, 0.5, 51)
#bins = np.linspace(-11, 0 , 55+1)
density = True

#plt.hist(nature['data_thrusts'], bins=bins, histtype='step', color='black', density=density)
simhist = plt.hist(synthetic['sim_thrusts'], bins=bins, histtype='step', color='orange', density=density)[0]
genhist = plt.hist(synthetic['gen_thrusts'], bins=bins, histtype='step', color='blue', density=density)[0]
genbhist = plt.hist(synthetic['genBefore_thrusts'], bins=bins, histtype='step', color='green', density=density)[0]

plt.yscale('log')

plt.show()

# %% [markdown]
# ## Specifying the Unfolding Problem

# %%
# how many iterations of the unfolding process
itnum = 5

# %%
# the observables to use for multifold (a single one just indicates unifold)
obs_multifold = ['Thrust']

# %%
# a dictionary to hold information about the observables
obs = {}

# %%
# the thrust and histogram style information

# 'xlim': (-11,0), 'ylim': (10**-6, 1), 'ylim_ratio': (0.7, 1.3),
# 'xlabel': r'$log\left(\tau\right)$', 'symbol': r'$\tau$',
# 'xlim': (0, 0.5), 'ylim': (10**-4.5, 100), 'ylim_ratio': (0.7, 1.3),
# 'xlabel': r'$\tau$', 'symbol': r'$\tau$',
obs.setdefault('Thrust', {}).update({
    'func': lambda dset, ptype: dset[ptype + '_thrusts'],
    'nbins_det': 50, 'nbins_mc': 50,
    'yscale': 'log',
    'xlim': (0, 0.5), 'ylim': (10**-4.5, 100), 'ylim_ratio': (0.7, 1.3),
    'ytick_ratio_step': 0.15,
    'xlabel': r'$\tau$', 'symbol': r'',
    'ylabel': r'Normalized Cross Section', 'ylabel_ratio': 'Ratio to\nALEPH',
    'stamp_xy': (0.5, 0.9),
    'legend_loc': 'lower left', 'legend_ncol': 1
})

# additional histogram and plot style information
hist_style = {'histtype': 'step', 'density': True, 'lw': 1, 'zorder': 2}
gen_style = {'linestyle': '--', 'color': 'blue', 'lw': 1.15, 'label': r'\textsc{Pythia} 6 Generation'}
truth_style = {'step': 'mid', 'edgecolor': 'green', 'facecolor': (0.75, 0.875, 0.75),
               'lw': 1.25, 'zorder': 0, 'label': 'ALEPH Measurement'}
ibu_style = {'ls': '-', 'marker': 'o', 'ms': 2.5, 'color': 'gray', 'zorder': 1}
omnifold_style = {'ls': '-', 'marker': 's', 'ms': 2.5, 'color': 'tab:red', 'zorder': 3}

# %%
# calculate quantities to be stored in obs
for obkey,ob in obs.items():
    
    # calculate observable for GEN, SIM, DATA, and TRUE
    ob['genobs'], ob['simobs'] = ob['func'](synthetic, 'gen'), ob['func'](synthetic, 'sim')
    ob['dataobs'] = ob['func'](nature, 'data')
    
    # setup bins
    ob['bins_det'] = np.linspace(ob['xlim'][0], ob['xlim'][1], ob['nbins_det']+1)
    ob['bins_mc'] = np.linspace(ob['xlim'][0], ob['xlim'][1], ob['nbins_mc']+1)
    ob['midbins_det'] = (ob['bins_det'][:-1] + ob['bins_det'][1:])/2
    ob['midbins_mc'] = (ob['bins_mc'][:-1] + ob['bins_mc'][1:])/2
    ob['binwidth_det'] = ob['bins_det'][1] - ob['bins_det'][0]
    ob['binwidth_mc'] = ob['bins_mc'][1] - ob['bins_mc'][0]
    
    # get the histograms of GEN, DATA, and TRUTH level observables
    ob['genobs_hist'] = np.histogram(ob['genobs'], bins=ob['bins_mc'], density=True)[0]
    ob['data_hist'] = np.histogram(ob['dataobs'], bins=ob['bins_det'], density=True)[0]

    # compute (and normalize) the response matrix between GEN and SIM
    ob['response'] = np.histogram2d(ob['simobs'], ob['genobs'], bins=(ob['bins_det'], ob['bins_mc']))[0]
    ob['response'] /= (ob['response'].sum(axis=0) + 10**-50)
    
    # perform iterative Bayesian unfolding
    ob['ibu_phis'] = ibu.ibu(ob['data_hist'], ob['response'], ob['genobs_hist'], 
                             ob['binwidth_det'], ob['binwidth_mc'], it=itnum)
    ob['ibu_phi_unc'] = ibu.ibu_unc(ob, it=itnum, nresamples=25)
    
    print('Done with', obkey)
# Out:
# Done with Thrust

# %%
from pyunfold import iterative_unfold

# %%
data, data_err = modplot.calc_hist(ob['dataobs'], bins=ob['bins_det'], density=True)[:2]
result = iterative_unfold(data=data, data_err=data_err,
                          response=ob['response'], response_err=0.1*np.ones(ob['response'].shape),
                          efficiencies=np.ones(len(genhist)),
                          efficiencies_err=0.001*np.ones(len(genhist)),
                          prior=ob['genobs_hist']/np.sum(ob['genobs_hist']),
                          max_iter=5, return_iterations=True, ts_stopping=0)

# %%
for i in range(1, 5):
    plt.plot(ob['midbins_det'], result['unfolded'][i]/(result['unfolded'][0] + 1e-50), 'o-', label=str(i))
plt.ylim(0.7, 1.3)
plt.xlabel('Thrust $T$')
plt.ylabel('Ratio of IBU iteration $n$ to 0')
plt.legend()
plt.show()

# %% [markdown]
# ## OmniFold

# %%
from keras.optimizers import Adam

# %%
model_layer_sizes = [100, 100, 100]
#model_layer_sizes = [100, 100, 100] # use this for the full network size

# set up the array of data/simulation detector-level observables
ob0 = obs_multifold[0]
X_det = np.asarray([np.concatenate((obs[obkey]['dataobs'], obs[obkey]['simobs'])) for obkey in obs_multifold]).T
Y_det = ef.utils.to_categorical(np.concatenate((np.ones(len(obs[ob0]['dataobs'])), 
                                                np.zeros(len(obs[ob0]['simobs'])))))

# set up the array of generation particle-level observables
X_gen = np.asarray([np.concatenate((obs[obkey]['genobs'], obs[obkey]['genobs'])) for obkey in obs_multifold]).T
Y_gen = ef.utils.to_categorical(np.concatenate((np.ones(len(obs[ob0]['genobs'])), 
                                                np.zeros(len(obs[ob0]['genobs'])))))

# standardize the inputs
X_det = (X_det - np.mean(X_det, axis=0))/np.std(X_det, axis=0)
X_gen = (X_gen - np.mean(X_gen, axis=0))/np.std(X_gen, axis=0)

# Specify the training parameters
# model parameters for the Step 1 network
det_args = {'input_dim': len(obs_multifold), 'dense_sizes': model_layer_sizes,
            'patience': 10, 'filepath': 'ptktraining/Step1_{}', 'save_weights_only': False,
            'modelcheck_opts': {'save_best_only': True, 'verbose': 1},
            'optimizer': Adam(lr=0.0005)
           }

# model parameters for the Step 2 network
mc_args = {'input_dim': len(obs_multifold), 'dense_sizes': model_layer_sizes, 
           'patience': 10, 'filepath': 'ptktraining/Step2_{}', 'save_weights_only': False, 
           'modelcheck_opts': {'save_best_only': True, 'verbose': 1},
           'optimizer': Adam(lr=0.0005)
          }

# general training parameters
#fitargs = {'batch_size': 500, 'epochs': 2, 'verbose': 1}
fitargs = {'batch_size': 100, 'epochs': 10, 'verbose': 1} # use this for a full training

# reweight the sim and data to have the same total weight to begin with
ndata, nsim = np.count_nonzero(Y_det[:,1]), np.count_nonzero(Y_det[:,0])
wdata = np.ones(ndata)
winit = ndata/nsim*np.ones(nsim)

# %%
# only run this if you want to re-train the OF model. Otherwise will used the saved version
if True:

    # apply the OmniFold procedure to get weights for the generation
    multifold_ws = omnifold.omnifold(X_gen, Y_gen, X_det, Y_det, wdata, winit,
                                     (ef.archs.DNN, det_args), (ef.archs.DNN, mc_args),
                                     fitargs, val=0.2, it=itnum, trw_ind=-2,
                                     weights_filename='ptktraining/ThrustNoCuts') #ptktraining/Log_ThrustNoCuts
# Out:
# WARNING:tensorflow:From /home/pkomiske/.local/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 100)               200
# _________________________________________________________________
# activation (Activation)      (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_1 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_2 (Activation)    (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 202
# _________________________________________________________________
# activation_3 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 20,602
# Trainable params: 20,602
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 100)               200
# _________________________________________________________________
# activation_4 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_5 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_6 (Activation)    (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 202
# _________________________________________________________________
# activation_7 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 20,602
# Trainable params: 20,602
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1709630 samples, validate on 427407 samples
# Epoch 1/10
# 1703600/1709630 [============================>.] - ETA: 0s - loss: 0.8861 - acc: 0.5044
# Epoch 00001: val_loss improved from inf to 0.88482, saving model to ptktraining/LogTau_Step1_0_Epoch-1.h5
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8861 - acc: 0.5048 - val_loss: 0.8848 - val_acc: 0.6226
# Epoch 2/10
# 1705800/1709630 [============================>.] - ETA: 0s - loss: 0.8851 - acc: 0.4831
# Epoch 00002: val_loss improved from 0.88482 to 0.88480, saving model to ptktraining/LogTau_Step1_0_Epoch-2.h5
# 1709630/1709630 [==============================] - 16s 10us/sample - loss: 0.8851 - acc: 0.4829 - val_loss: 0.8848 - val_acc: 0.3625
# Epoch 3/10
# 1709600/1709630 [============================>.] - ETA: 0s - loss: 0.8850 - acc: 0.4876
# Epoch 00003: val_loss did not improve from 0.88480
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8850 - acc: 0.4876 - val_loss: 0.8849 - val_acc: 0.6330
# Epoch 4/10
# 1709630/1709630 [==============================] - ETA: 0s - loss: 0.8850 - acc: 0.4895
# Epoch 00004: val_loss improved from 0.88480 to 0.88476, saving model to ptktraining/LogTau_Step1_0_Epoch-4.h5
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8850 - acc: 0.4895 - val_loss: 0.8848 - val_acc: 0.6269
# Epoch 5/10
# 1703200/1709630 [============================>.] - ETA: 0s - loss: 0.8850 - acc: 0.4879
# Epoch 00005: val_loss did not improve from 0.88476
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8850 - acc: 0.4874 - val_loss: 0.8848 - val_acc: 0.3626
# Epoch 6/10
# 1708700/1709630 [============================>.] - ETA: 0s - loss: 0.8850 - acc: 0.4913
# Epoch 00006: val_loss did not improve from 0.88476
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8850 - acc: 0.4913 - val_loss: 0.8848 - val_acc: 0.3622
# Epoch 7/10
# 1709500/1709630 [============================>.] - ETA: 0s - loss: 0.8850 - acc: 0.4903
# Epoch 00007: val_loss did not improve from 0.88476
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8850 - acc: 0.4903 - val_loss: 0.8848 - val_acc: 0.6264
# Epoch 8/10
# 1702800/1709630 [============================>.] - ETA: 0s - loss: 0.8850 - acc: 0.4891
# Epoch 00008: val_loss did not improve from 0.88476
# 1709630/1709630 [==============================] - 16s 10us/sample - loss: 0.8850 - acc: 0.4893 - val_loss: 0.8849 - val_acc: 0.6303
# Epoch 9/10
# 1709200/1709630 [============================>.] - ETA: 0s - loss: 0.8850 - acc: 0.4841
# Epoch 00009: val_loss did not improve from 0.88476
# 1709630/1709630 [==============================] - 16s 10us/sample - loss: 0.8850 - acc: 0.4841 - val_loss: 0.8848 - val_acc: 0.6282
# Epoch 10/10
# 1707400/1709630 [============================>.] - ETA: 0s - loss: 0.8850 - acc: 0.4842
# Epoch 00010: val_loss did not improve from 0.88476
# 1709630/1709630 [==============================] - 16s 9us/sample - loss: 0.8850 - acc: 0.4840 - val_loss: 0.8848 - val_acc: 0.3622
# /home/pkomiske/Dropbox (MIT)/Research/ALEPHOpenData/python/omnifold.py:31: RuntimeWarning: divide by zero encountered in true_divide
#   w *= np.clip(preds/(1 - preds + 10**-50), fitargs.get('weight_clip_min', 0.), fitargs.get('weight_clip_max', np.inf))
# Train on 1234556 samples, validate on 308638 samples
# Epoch 1/10
# 1232700/1234556 [============================>.] - ETA: 0s - loss: 1.2257 - acc: 0.4998
# Epoch 00001: val_loss improved from inf to 1.22423, saving model to ptktraining/LogTau_Step2_0_Epoch-1.h5
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2257 - acc: 0.4998 - val_loss: 1.2242 - val_acc: 0.5000
# Epoch 2/10
# 1227800/1234556 [============================>.] - ETA: 0s - loss: 1.2244 - acc: 0.5005
# Epoch 00002: val_loss improved from 1.22423 to 1.22422, saving model to ptktraining/LogTau_Step2_0_Epoch-2.h5
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2244 - acc: 0.5005 - val_loss: 1.2242 - val_acc: 0.5000
# Epoch 3/10
# 1232000/1234556 [============================>.] - ETA: 0s - loss: 1.2244 - acc: 0.4988
# Epoch 00003: val_loss improved from 1.22422 to 1.22422, saving model to ptktraining/LogTau_Step2_0_Epoch-3.h5
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2244 - acc: 0.4989 - val_loss: 1.2242 - val_acc: 0.5000
# Epoch 4/10
# 1230800/1234556 [============================>.] - ETA: 0s - loss: 1.2244 - acc: 0.5001
# Epoch 00004: val_loss did not improve from 1.22422
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2244 - acc: 0.5001 - val_loss: 1.2242 - val_acc: 0.5000
# Epoch 5/10
# 1229500/1234556 [============================>.] - ETA: 0s - loss: 1.2244 - acc: 0.5003
# Epoch 00005: val_loss did not improve from 1.22422
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2244 - acc: 0.5003 - val_loss: 1.2242 - val_acc: 0.5000
# Epoch 6/10
# 1231000/1234556 [============================>.] - ETA: 0s - loss: 1.2244 - acc: 0.5002
# Epoch 00006: val_loss did not improve from 1.22422
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2244 - acc: 0.5002 - val_loss: 1.2242 - val_acc: 0.5000
# Epoch 7/10
# 1231900/1234556 [============================>.] - ETA: 0s - loss: 1.2244 - acc: 0.5004
# Epoch 00007: val_loss did not improve from 1.22422
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2244 - acc: 0.5004 - val_loss: 1.2243 - val_acc: 0.5000
# Epoch 8/10
# 1230800/1234556 [============================>.] - ETA: 0s - loss: 1.2244 - acc: 0.5006
# Epoch 00008: val_loss improved from 1.22422 to 1.22422, saving model to ptktraining/LogTau_Step2_0_Epoch-8.h5
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2244 - acc: 0.5006 - val_loss: 1.2242 - val_acc: 0.5000
# Epoch 9/10
# 1228400/1234556 [============================>.] - ETA: 0s - loss: 1.2244 - acc: 0.4994
# Epoch 00009: val_loss did not improve from 1.22422
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2244 - acc: 0.4994 - val_loss: 1.2242 - val_acc: 0.5000
# Epoch 10/10
# 1231200/1234556 [============================>.] - ETA: 0s - loss: 1.2244 - acc: 0.4999
# Epoch 00010: val_loss did not improve from 1.22422
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2244 - acc: 0.5000 - val_loss: 1.2243 - val_acc: 0.5000
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 100)               200
# _________________________________________________________________
# activation_8 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_9 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_10 (Activation)   (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 202
# _________________________________________________________________
# activation_11 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 20,602
# Trainable params: 20,602
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 100)               200
# _________________________________________________________________
# activation_12 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_13 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_14 (Activation)   (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 202
# _________________________________________________________________
# activation_15 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 20,602
# Trainable params: 20,602
# Non-trainable params: 0
# _________________________________________________________________
# loading models from previous iteration:
# ptktraining/LogTau_Step1_0 ptktraining/LogTau_Step2_0
# Train on 1709630 samples, validate on 427407 samples
# Epoch 1/10
# 1704900/1709630 [============================>.] - ETA: 0s - loss: 0.8929 - acc: 0.3755
# Epoch 00001: val_loss improved from inf to 0.89273, saving model to ptktraining/LogTau_Step1_1_Epoch-1.h5
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8929 - acc: 0.3755 - val_loss: 0.8927 - val_acc: 0.3622
# Epoch 2/10
# 1705500/1709630 [============================>.] - ETA: 0s - loss: 0.8929 - acc: 0.3692
# Epoch 00002: val_loss did not improve from 0.89273
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8929 - acc: 0.3692 - val_loss: 0.8928 - val_acc: 0.3625
# Epoch 3/10
# 1704800/1709630 [============================>.] - ETA: 0s - loss: 0.8929 - acc: 0.3733
# Epoch 00003: val_loss improved from 0.89273 to 0.89269, saving model to ptktraining/LogTau_Step1_1_Epoch-3.h5
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8929 - acc: 0.3732 - val_loss: 0.8927 - val_acc: 0.3624
# Epoch 4/10
# 1709100/1709630 [============================>.] - ETA: 0s - loss: 0.8929 - acc: 0.3705
# Epoch 00004: val_loss did not improve from 0.89269
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8929 - acc: 0.3705 - val_loss: 0.8927 - val_acc: 0.3623
# Epoch 5/10
# 1703600/1709630 [============================>.] - ETA: 0s - loss: 0.8929 - acc: 0.3730
# Epoch 00005: val_loss did not improve from 0.89269
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8929 - acc: 0.3739 - val_loss: 0.8928 - val_acc: 0.6196
# Epoch 6/10
# 1707100/1709630 [============================>.] - ETA: 0s - loss: 0.8929 - acc: 0.3747
# Epoch 00006: val_loss did not improve from 0.89269
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8929 - acc: 0.3747 - val_loss: 0.8927 - val_acc: 0.3624
# Epoch 7/10
# 1703800/1709630 [============================>.] - ETA: 0s - loss: 0.8929 - acc: 0.3728
# Epoch 00007: val_loss improved from 0.89269 to 0.89268, saving model to ptktraining/LogTau_Step1_1_Epoch-7.h5
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8929 - acc: 0.3728 - val_loss: 0.8927 - val_acc: 0.3624
# Epoch 8/10
# 1706500/1709630 [============================>.] - ETA: 0s - loss: 0.8929 - acc: 0.3756
# Epoch 00008: val_loss did not improve from 0.89268
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8929 - acc: 0.3756 - val_loss: 0.8927 - val_acc: 0.3623
# Epoch 9/10
# 1705900/1709630 [============================>.] - ETA: 0s - loss: 0.8929 - acc: 0.3699
# Epoch 00009: val_loss did not improve from 0.89268
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8929 - acc: 0.3699 - val_loss: 0.8927 - val_acc: 0.3624
# Epoch 10/10
# 1705600/1709630 [============================>.] - ETA: 0s - loss: 0.8929 - acc: 0.3715
# Epoch 00010: val_loss did not improve from 0.89268
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8929 - acc: 0.3715 - val_loss: 0.8927 - val_acc: 0.3626
# Train on 1234556 samples, validate on 308638 samples
# Epoch 1/10
# 1232100/1234556 [============================>.] - ETA: 0s - loss: 1.2310 - acc: 0.5000
# Epoch 00001: val_loss improved from inf to 1.22982, saving model to ptktraining/LogTau_Step2_1_Epoch-1.h5
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2310 - acc: 0.5000 - val_loss: 1.2298 - val_acc: 0.5000
# Epoch 2/10
# 1232700/1234556 [============================>.] - ETA: 0s - loss: 1.2310 - acc: 0.5001
# Epoch 00002: val_loss improved from 1.22982 to 1.22980, saving model to ptktraining/LogTau_Step2_1_Epoch-2.h5
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2310 - acc: 0.5000 - val_loss: 1.2298 - val_acc: 0.5000
# Epoch 3/10
# 1228300/1234556 [============================>.] - ETA: 0s - loss: 1.2310 - acc: 0.5001
# Epoch 00003: val_loss improved from 1.22980 to 1.22980, saving model to ptktraining/LogTau_Step2_1_Epoch-3.h5
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2310 - acc: 0.5001 - val_loss: 1.2298 - val_acc: 0.5000
# Epoch 4/10
# 1233900/1234556 [============================>.] - ETA: 0s - loss: 1.2310 - acc: 0.5001
# Epoch 00004: val_loss improved from 1.22980 to 1.22980, saving model to ptktraining/LogTau_Step2_1_Epoch-4.h5
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2310 - acc: 0.5001 - val_loss: 1.2298 - val_acc: 0.5000
# Epoch 5/10
# 1234200/1234556 [============================>.] - ETA: 0s - loss: 1.2310 - acc: 0.5000
# Epoch 00005: val_loss improved from 1.22980 to 1.22980, saving model to ptktraining/LogTau_Step2_1_Epoch-5.h5
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2310 - acc: 0.5000 - val_loss: 1.2298 - val_acc: 0.5000
# Epoch 6/10
# 1232900/1234556 [============================>.] - ETA: 0s - loss: 1.2310 - acc: 0.5000
# Epoch 00006: val_loss did not improve from 1.22980
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2310 - acc: 0.5000 - val_loss: 1.2298 - val_acc: 0.5000
# Epoch 7/10
# 1232800/1234556 [============================>.] - ETA: 0s - loss: 1.2310 - acc: 0.5001
# Epoch 00007: val_loss did not improve from 1.22980
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2310 - acc: 0.5001 - val_loss: 1.2299 - val_acc: 0.5000
# Epoch 8/10
# 1231600/1234556 [============================>.] - ETA: 0s - loss: 1.2310 - acc: 0.5000
# Epoch 00008: val_loss did not improve from 1.22980
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2310 - acc: 0.5000 - val_loss: 1.2299 - val_acc: 0.5000
# Epoch 9/10
# 1230300/1234556 [============================>.] - ETA: 0s - loss: 1.2310 - acc: 0.5002
# Epoch 00009: val_loss did not improve from 1.22980
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2310 - acc: 0.5002 - val_loss: 1.2299 - val_acc: 0.5000
# Epoch 10/10
# 1228400/1234556 [============================>.] - ETA: 0s - loss: 1.2310 - acc: 0.5000
# Epoch 00010: val_loss did not improve from 1.22980
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2310 - acc: 0.5000 - val_loss: 1.2298 - val_acc: 0.5000
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 100)               200
# _________________________________________________________________
# activation_16 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_17 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_18 (Activation)   (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 202
# _________________________________________________________________
# activation_19 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 20,602
# Trainable params: 20,602
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 100)               200
# _________________________________________________________________
# activation_20 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_21 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_22 (Activation)   (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 202
# _________________________________________________________________
# activation_23 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 20,602
# Trainable params: 20,602
# Non-trainable params: 0
# _________________________________________________________________
# loading models from previous iteration:
# ptktraining/LogTau_Step1_1 ptktraining/LogTau_Step2_1
# Train on 1709630 samples, validate on 427407 samples
# Epoch 1/10
# 1704400/1709630 [============================>.] - ETA: 0s - loss: 0.8742 - acc: 0.6253
# Epoch 00001: val_loss improved from inf to 0.87397, saving model to ptktraining/LogTau_Step1_2_Epoch-1.h5
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8741 - acc: 0.6253 - val_loss: 0.8740 - val_acc: 0.6205
# Epoch 2/10
# 1708500/1709630 [============================>.] - ETA: 0s - loss: 0.8741 - acc: 0.6219
# Epoch 00002: val_loss did not improve from 0.87397
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8741 - acc: 0.6218 - val_loss: 0.8741 - val_acc: 0.6012
# Epoch 3/10
# 1706200/1709630 [============================>.] - ETA: 0s - loss: 0.8742 - acc: 0.6220
# Epoch 00003: val_loss did not improve from 0.87397
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8741 - acc: 0.6220 - val_loss: 0.8741 - val_acc: 0.6393
# Epoch 4/10
# 1707500/1709630 [============================>.] - ETA: 0s - loss: 0.8741 - acc: 0.6257
# Epoch 00004: val_loss improved from 0.87397 to 0.87395, saving model to ptktraining/LogTau_Step1_2_Epoch-4.h5
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8741 - acc: 0.6257 - val_loss: 0.8740 - val_acc: 0.6273
# Epoch 5/10
# 1706900/1709630 [============================>.] - ETA: 0s - loss: 0.8741 - acc: 0.6240
# Epoch 00005: val_loss did not improve from 0.87395
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8741 - acc: 0.6240 - val_loss: 0.8740 - val_acc: 0.6241
# Epoch 6/10
# 1707900/1709630 [============================>.] - ETA: 0s - loss: 0.8741 - acc: 0.6226
# Epoch 00006: val_loss did not improve from 0.87395
# 1709630/1709630 [==============================] - 18s 11us/sample - loss: 0.8741 - acc: 0.6226 - val_loss: 0.8740 - val_acc: 0.6123
# Epoch 7/10
# 1707700/1709630 [============================>.] - ETA: 0s - loss: 0.8742 - acc: 0.6254
# Epoch 00007: val_loss improved from 0.87395 to 0.87393, saving model to ptktraining/LogTau_Step1_2_Epoch-7.h5
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8741 - acc: 0.6254 - val_loss: 0.8739 - val_acc: 0.6125
# Epoch 8/10
# 1708500/1709630 [============================>.] - ETA: 0s - loss: 0.8741 - acc: 0.5973
# Epoch 00008: val_loss improved from 0.87393 to 0.87392, saving model to ptktraining/LogTau_Step1_2_Epoch-8.h5
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8741 - acc: 0.5973 - val_loss: 0.8739 - val_acc: 0.6291
# Epoch 9/10
# 1706900/1709630 [============================>.] - ETA: 0s - loss: 0.8741 - acc: 0.5838
# Epoch 00009: val_loss did not improve from 0.87392
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8741 - acc: 0.5839 - val_loss: 0.8741 - val_acc: 0.6377
# Epoch 10/10
# 1709400/1709630 [============================>.] - ETA: 0s - loss: 0.8741 - acc: 0.5873
# Epoch 00010: val_loss improved from 0.87392 to 0.87391, saving model to ptktraining/LogTau_Step1_2_Epoch-10.h5
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8741 - acc: 0.5873 - val_loss: 0.8739 - val_acc: 0.5672
# Train on 1234556 samples, validate on 308638 samples
# Epoch 1/10
# 1231100/1234556 [============================>.] - ETA: 0s - loss: 1.2087 - acc: 0.5000
# Epoch 00001: val_loss improved from inf to 1.20850, saving model to ptktraining/LogTau_Step2_2_Epoch-1.h5
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2087 - acc: 0.5000 - val_loss: 1.2085 - val_acc: 0.5000
# Epoch 2/10
# 1234556/1234556 [==============================] - ETA: 0s - loss: 1.2087 - acc: 0.4998
# Epoch 00002: val_loss improved from 1.20850 to 1.20849, saving model to ptktraining/LogTau_Step2_2_Epoch-2.h5
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2087 - acc: 0.4998 - val_loss: 1.2085 - val_acc: 0.5000
# Epoch 3/10
# 1229700/1234556 [============================>.] - ETA: 0s - loss: 1.2087 - acc: 0.4999
# Epoch 00003: val_loss did not improve from 1.20849
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2087 - acc: 0.4999 - val_loss: 1.2085 - val_acc: 0.5000
# Epoch 4/10
# 1229900/1234556 [============================>.] - ETA: 0s - loss: 1.2087 - acc: 0.5001
# Epoch 00004: val_loss did not improve from 1.20849
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2087 - acc: 0.5001 - val_loss: 1.2085 - val_acc: 0.5000
# Epoch 5/10
# 1231800/1234556 [============================>.] - ETA: 0s - loss: 1.2087 - acc: 0.4999
# Epoch 00005: val_loss did not improve from 1.20849
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2087 - acc: 0.4999 - val_loss: 1.2085 - val_acc: 0.5000
# Epoch 6/10
# 1231200/1234556 [============================>.] - ETA: 0s - loss: 1.2087 - acc: 0.4999
# Epoch 00006: val_loss did not improve from 1.20849
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2087 - acc: 0.4999 - val_loss: 1.2085 - val_acc: 0.5000
# Epoch 7/10
# 1232000/1234556 [============================>.] - ETA: 0s - loss: 1.2087 - acc: 0.5000
# Epoch 00007: val_loss improved from 1.20849 to 1.20849, saving model to ptktraining/LogTau_Step2_2_Epoch-7.h5
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2087 - acc: 0.5000 - val_loss: 1.2085 - val_acc: 0.5000
# Epoch 8/10
# 1229600/1234556 [============================>.] - ETA: 0s - loss: 1.2087 - acc: 0.4998
# Epoch 00008: val_loss did not improve from 1.20849
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2087 - acc: 0.4999 - val_loss: 1.2085 - val_acc: 0.5000
# Epoch 9/10
# 1231300/1234556 [============================>.] - ETA: 0s - loss: 1.2087 - acc: 0.4999
# Epoch 00009: val_loss did not improve from 1.20849
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2087 - acc: 0.4999 - val_loss: 1.2085 - val_acc: 0.5000
# Epoch 10/10
# 1229100/1234556 [============================>.] - ETA: 0s - loss: 1.2087 - acc: 0.5001
# Epoch 00010: val_loss did not improve from 1.20849
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2087 - acc: 0.5001 - val_loss: 1.2085 - val_acc: 0.5000
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 100)               200
# _________________________________________________________________
# activation_24 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_25 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_26 (Activation)   (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 202
# _________________________________________________________________
# activation_27 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 20,602
# Trainable params: 20,602
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 100)               200
# _________________________________________________________________
# activation_28 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_29 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_30 (Activation)   (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 202
# _________________________________________________________________
# activation_31 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 20,602
# Trainable params: 20,602
# Non-trainable params: 0
# _________________________________________________________________
# loading models from previous iteration:
# ptktraining/LogTau_Step1_2 ptktraining/LogTau_Step2_2
# Train on 1709630 samples, validate on 427407 samples
# Epoch 1/10
# 1707300/1709630 [============================>.] - ETA: 0s - loss: 0.8876 - acc: 0.4789
# Epoch 00001: val_loss improved from inf to 0.88746, saving model to ptktraining/LogTau_Step1_3_Epoch-1.h5
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8876 - acc: 0.4789 - val_loss: 0.8875 - val_acc: 0.4889
# Epoch 2/10
# 1704900/1709630 [============================>.] - ETA: 0s - loss: 0.8876 - acc: 0.4834
# Epoch 00002: val_loss did not improve from 0.88746
# 1709630/1709630 [==============================] - 19s 11us/sample - loss: 0.8876 - acc: 0.4831 - val_loss: 0.8875 - val_acc: 0.3637
# Epoch 3/10
# 1704000/1709630 [============================>.] - ETA: 0s - loss: 0.8876 - acc: 0.4759
# Epoch 00003: val_loss did not improve from 0.88746
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8876 - acc: 0.4760 - val_loss: 0.8875 - val_acc: 0.5354
# Epoch 4/10
# 1707100/1709630 [============================>.] - ETA: 0s - loss: 0.8876 - acc: 0.4916
# Epoch 00004: val_loss did not improve from 0.88746
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8876 - acc: 0.4915 - val_loss: 0.8875 - val_acc: 0.4167
# Epoch 5/10
# 1708900/1709630 [============================>.] - ETA: 0s - loss: 0.8876 - acc: 0.4775
# Epoch 00005: val_loss improved from 0.88746 to 0.88743, saving model to ptktraining/LogTau_Step1_3_Epoch-5.h5
# 1709630/1709630 [==============================] - 19s 11us/sample - loss: 0.8876 - acc: 0.4775 - val_loss: 0.8874 - val_acc: 0.5153
# Epoch 6/10
# 1706600/1709630 [============================>.] - ETA: 0s - loss: 0.8876 - acc: 0.4816
# Epoch 00006: val_loss did not improve from 0.88743
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8876 - acc: 0.4815 - val_loss: 0.8874 - val_acc: 0.4505
# Epoch 7/10
# 1706600/1709630 [============================>.] - ETA: 0s - loss: 0.8876 - acc: 0.4766
# Epoch 00007: val_loss did not improve from 0.88743
# 1709630/1709630 [==============================] - 18s 11us/sample - loss: 0.8876 - acc: 0.4766 - val_loss: 0.8874 - val_acc: 0.5266
# Epoch 8/10
# 1705700/1709630 [============================>.] - ETA: 0s - loss: 0.8876 - acc: 0.4826
# Epoch 00008: val_loss did not improve from 0.88743
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8876 - acc: 0.4826 - val_loss: 0.8874 - val_acc: 0.5133
# Epoch 9/10
# 1706800/1709630 [============================>.] - ETA: 0s - loss: 0.8876 - acc: 0.4692
# Epoch 00009: val_loss did not improve from 0.88743
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8876 - acc: 0.4692 - val_loss: 0.8875 - val_acc: 0.4322
# Epoch 10/10
# 1703600/1709630 [============================>.] - ETA: 0s - loss: 0.8876 - acc: 0.4717
# Epoch 00010: val_loss did not improve from 0.88743
# 1709630/1709630 [==============================] - 19s 11us/sample - loss: 0.8876 - acc: 0.4716 - val_loss: 0.8875 - val_acc: 0.4028
# Train on 1234556 samples, validate on 308638 samples
# Epoch 1/10
# 1230200/1234556 [============================>.] - ETA: 0s - loss: 1.2218 - acc: 0.5000
# Epoch 00001: val_loss improved from inf to 1.22137, saving model to ptktraining/LogTau_Step2_3_Epoch-1.h5
# 1234556/1234556 [==============================] - 13s 11us/sample - loss: 1.2218 - acc: 0.5000 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 2/10
# 1232600/1234556 [============================>.] - ETA: 0s - loss: 1.2218 - acc: 0.5000
# Epoch 00002: val_loss did not improve from 1.22137
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2218 - acc: 0.5000 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 3/10
# 1232300/1234556 [============================>.] - ETA: 0s - loss: 1.2218 - acc: 0.4999
# Epoch 00003: val_loss did not improve from 1.22137
# 1234556/1234556 [==============================] - 14s 11us/sample - loss: 1.2218 - acc: 0.4999 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 4/10
# 1230500/1234556 [============================>.] - ETA: 0s - loss: 1.2218 - acc: 0.5001
# Epoch 00004: val_loss did not improve from 1.22137
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2218 - acc: 0.5001 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 5/10
# 1232900/1234556 [============================>.] - ETA: 0s - loss: 1.2218 - acc: 0.4998
# Epoch 00005: val_loss did not improve from 1.22137
# 1234556/1234556 [==============================] - 13s 11us/sample - loss: 1.2218 - acc: 0.4998 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 6/10
# 1231600/1234556 [============================>.] - ETA: 0s - loss: 1.2217 - acc: 0.5000
# Epoch 00006: val_loss did not improve from 1.22137
# 1234556/1234556 [==============================] - 12s 10us/sample - loss: 1.2218 - acc: 0.5000 - val_loss: 1.2215 - val_acc: 0.5000
# Epoch 7/10
# 1230300/1234556 [============================>.] - ETA: 0s - loss: 1.2218 - acc: 0.4999
# Epoch 00007: val_loss did not improve from 1.22137
# 1234556/1234556 [==============================] - 13s 11us/sample - loss: 1.2218 - acc: 0.4999 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 8/10
# 1230800/1234556 [============================>.] - ETA: 0s - loss: 1.2218 - acc: 0.4999
# Epoch 00008: val_loss did not improve from 1.22137
# 1234556/1234556 [==============================] - 13s 11us/sample - loss: 1.2218 - acc: 0.4999 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 9/10
# 1232700/1234556 [============================>.] - ETA: 0s - loss: 1.2218 - acc: 0.4999
# Epoch 00009: val_loss did not improve from 1.22137
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2218 - acc: 0.4999 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 10/10
# 1231400/1234556 [============================>.] - ETA: 0s - loss: 1.2218 - acc: 0.5002
# Epoch 00010: val_loss did not improve from 1.22137
# 1234556/1234556 [==============================] - 13s 11us/sample - loss: 1.2218 - acc: 0.5002 - val_loss: 1.2214 - val_acc: 0.5000
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 100)               200
# _________________________________________________________________
# activation_32 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_33 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_34 (Activation)   (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 202
# _________________________________________________________________
# activation_35 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 20,602
# Trainable params: 20,602
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 100)               200
# _________________________________________________________________
# activation_36 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_37 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_38 (Activation)   (None, 100)               0
# _________________________________________________________________
# output (Dense)               (None, 2)                 202
# _________________________________________________________________
# activation_39 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 20,602
# Trainable params: 20,602
# Non-trainable params: 0
# _________________________________________________________________
# loading models from previous iteration:
# ptktraining/LogTau_Step1_3 ptktraining/LogTau_Step2_3
# Train on 1709630 samples, validate on 427407 samples
# Epoch 1/10
# 1704200/1709630 [============================>.] - ETA: 0s - loss: 0.8866 - acc: 0.4876
# Epoch 00001: val_loss improved from inf to 0.88646, saving model to ptktraining/LogTau_Step1_4_Epoch-1.h5
# 1709630/1709630 [==============================] - 18s 11us/sample - loss: 0.8866 - acc: 0.4877 - val_loss: 0.8865 - val_acc: 0.5175
# Epoch 2/10
# 1708200/1709630 [============================>.] - ETA: 0s - loss: 0.8866 - acc: 0.4960
# Epoch 00002: val_loss did not improve from 0.88646
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8866 - acc: 0.4960 - val_loss: 0.8865 - val_acc: 0.4267
# Epoch 3/10
# 1704000/1709630 [============================>.] - ETA: 0s - loss: 0.8866 - acc: 0.4876
# Epoch 00003: val_loss did not improve from 0.88646
# 1709630/1709630 [==============================] - 18s 11us/sample - loss: 0.8866 - acc: 0.4876 - val_loss: 0.8865 - val_acc: 0.5245
# Epoch 4/10
# 1706200/1709630 [============================>.] - ETA: 0s - loss: 0.8866 - acc: 0.4921
# Epoch 00004: val_loss did not improve from 0.88646
# 1709630/1709630 [==============================] - 17s 10us/sample - loss: 0.8866 - acc: 0.4921 - val_loss: 0.8865 - val_acc: 0.4370
# Epoch 5/10
# 1704900/1709630 [============================>.] - ETA: 0s - loss: 0.8867 - acc: 0.4903
# Epoch 00005: val_loss did not improve from 0.88646
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8866 - acc: 0.4905 - val_loss: 0.8865 - val_acc: 0.5508
# Epoch 6/10
# 1704000/1709630 [============================>.] - ETA: 0s - loss: 0.8866 - acc: 0.4951
# Epoch 00006: val_loss did not improve from 0.88646
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8866 - acc: 0.4947 - val_loss: 0.8865 - val_acc: 0.3822
# Epoch 7/10
# 1706800/1709630 [============================>.] - ETA: 0s - loss: 0.8866 - acc: 0.4890
# Epoch 00007: val_loss did not improve from 0.88646
# 1709630/1709630 [==============================] - 18s 11us/sample - loss: 0.8866 - acc: 0.4892 - val_loss: 0.8865 - val_acc: 0.5834
# Epoch 8/10
# 1709300/1709630 [============================>.] - ETA: 0s - loss: 0.8866 - acc: 0.4895
# Epoch 00008: val_loss improved from 0.88646 to 0.88646, saving model to ptktraining/LogTau_Step1_4_Epoch-8.h5
# 1709630/1709630 [==============================] - 18s 11us/sample - loss: 0.8866 - acc: 0.4894 - val_loss: 0.8865 - val_acc: 0.4609
# Epoch 9/10
# 1708400/1709630 [============================>.] - ETA: 0s - loss: 0.8866 - acc: 0.4844
# Epoch 00009: val_loss did not improve from 0.88646
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8866 - acc: 0.4843 - val_loss: 0.8866 - val_acc: 0.3624
# Epoch 10/10
# 1708800/1709630 [============================>.] - ETA: 0s - loss: 0.8866 - acc: 0.4841
# Epoch 00010: val_loss did not improve from 0.88646
# 1709630/1709630 [==============================] - 18s 10us/sample - loss: 0.8866 - acc: 0.4840 - val_loss: 0.8865 - val_acc: 0.4135
# Train on 1234556 samples, validate on 308638 samples
# Epoch 1/10
# 1229000/1234556 [============================>.] - ETA: 0s - loss: 1.2225 - acc: 0.5004
# Epoch 00001: val_loss improved from inf to 1.22140, saving model to ptktraining/LogTau_Step2_4_Epoch-1.h5
# 1234556/1234556 [==============================] - 14s 11us/sample - loss: 1.2225 - acc: 0.5004 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 2/10
# 1231400/1234556 [============================>.] - ETA: 0s - loss: 1.2225 - acc: 0.5002
# Epoch 00002: val_loss did not improve from 1.22140
# 1234556/1234556 [==============================] - 13s 11us/sample - loss: 1.2225 - acc: 0.5002 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 3/10
# 1234200/1234556 [============================>.] - ETA: 0s - loss: 1.2225 - acc: 0.5001
# Epoch 00003: val_loss improved from 1.22140 to 1.22135, saving model to ptktraining/LogTau_Step2_4_Epoch-3.h5
# 1234556/1234556 [==============================] - 13s 11us/sample - loss: 1.2225 - acc: 0.5001 - val_loss: 1.2213 - val_acc: 0.5000
# Epoch 4/10
# 1232700/1234556 [============================>.] - ETA: 0s - loss: 1.2225 - acc: 0.4998
# Epoch 00004: val_loss did not improve from 1.22135
# 1234556/1234556 [==============================] - 14s 11us/sample - loss: 1.2225 - acc: 0.4998 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 5/10
# 1234500/1234556 [============================>.] - ETA: 0s - loss: 1.2225 - acc: 0.4998
# Epoch 00005: val_loss did not improve from 1.22135
# 1234556/1234556 [==============================] - 13s 11us/sample - loss: 1.2225 - acc: 0.4998 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 6/10
# 1230600/1234556 [============================>.] - ETA: 0s - loss: 1.2225 - acc: 0.4996
# Epoch 00006: val_loss improved from 1.22135 to 1.22135, saving model to ptktraining/LogTau_Step2_4_Epoch-6.h5
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2225 - acc: 0.4996 - val_loss: 1.2213 - val_acc: 0.5000
# Epoch 7/10
# 1233700/1234556 [============================>.] - ETA: 0s - loss: 1.2225 - acc: 0.5000
# Epoch 00007: val_loss did not improve from 1.22135
# 1234556/1234556 [==============================] - 14s 11us/sample - loss: 1.2225 - acc: 0.5001 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 8/10
# 1230000/1234556 [============================>.] - ETA: 0s - loss: 1.2225 - acc: 0.4998
# Epoch 00008: val_loss did not improve from 1.22135
# 1234556/1234556 [==============================] - 13s 10us/sample - loss: 1.2225 - acc: 0.4998 - val_loss: 1.2215 - val_acc: 0.5000
# Epoch 9/10
# 1230800/1234556 [============================>.] - ETA: 0s - loss: 1.2225 - acc: 0.4996
# Epoch 00009: val_loss did not improve from 1.22135
# 1234556/1234556 [==============================] - 13s 11us/sample - loss: 1.2225 - acc: 0.4996 - val_loss: 1.2214 - val_acc: 0.5000
# Epoch 10/10
# 1228300/1234556 [============================>.] - ETA: 0s - loss: 1.2225 - acc: 0.5001
# Epoch 00010: val_loss did not improve from 1.22135
# 1234556/1234556 [==============================] - 13s 11us/sample - loss: 1.2225 - acc: 0.5001 - val_loss: 1.2213 - val_acc: 0.5000

# %% [markdown]
# ## Plot Unfolding Results

# %%
with open('HEPData-ins636645-v1-Table_54.csv', 'r') as f:
    
    vals = []
    for row in f:
        if row.startswith('#'):
            continue
            
        if row.startswith('T'):
            print(row.strip())
        else:
            vals.append(row.strip().split(','))
            
hepdata = np.asarray(vals, dtype=float)
# Out:
# THRUST,THRUST LOW,THRUST HIGH,(1/SIG)*D(SIG)/DTHRUST,stat +,stat -,sys_1 +,sys_1 -,sys_2 +,sys_2 -

# %%
multifold_ws = np.load('ptktraining/ThrustNoCuts.npy')

# %%
plt.hist(multifold_ws[3], bins=50, histtype='step')
plt.show()

# %%
corrs = genbhist/(genhist + 10**-50)
print(len(corrs))
# Out:
# 50

# %%
#corrs = np.ones(len(genhist))

# %%
obs.keys()
# Out:
# dict_keys(['Thrust'])

# %%
i = 0
obkey = 'Thrust'
ob = obs['Thrust']

for itnum in range(6):
    
    # get the styled axes on which to plot
    fig, [ax0, ax1] = modplot.axes(**ob, gridspec_update={'height_ratios': (2, 1)})
    if ob.get('yscale') is not None:
        ax0.set_yscale(ob['yscale'])

    # Plot the Different Distributions of the Observable
    # plot the "data" histogram of the observable
    ax0.hist(ob['dataobs'], bins=ob['bins_det'], color='black', label='ALEPH Open Data', **hist_style)

    # plot the "sim" histogram of the observable
    ax0.hist(ob['simobs'], bins=ob['bins_det'], color='orange', label=r'\textsc{Pythia} 6 Reconstruction', **hist_style)

    # plot the "gen" histogram of the observable
    ax0.plot(ob['midbins_mc'], ob['genobs_hist'], **gen_style)

    # plot the "truth" histogram of the observable
    #ax0.fill_between(ob['midbins_mc'], ob['truth_hist'], **truth_style)
    aleph_midbins = 1 - hepdata[::-1,0]
    aleph_thrust = hepdata[::-1,3]
    aleph_errs = np.linalg.norm(hepdata[::-1,[-1,-3,-5]], axis=1)
    ax0.fill_between(aleph_midbins, aleph_thrust, **truth_style)
    
    # Plot the Unfolded Distributions of the Observable
    # plot the OmniFold distribution
    of_histgen, of_histgen_unc = modplot.calc_hist(ob['genobs'], weights=multifold_ws[-1], 
                                                   bins=ob['bins_mc'], density=True)[:2]
    of_histgen *= corrs
    of_histgen_unc *= corrs
    ax0.plot(ob['midbins_mc'], of_histgen, **omnifold_style, label=r'UniFold')

    # plot the IBU distribution
    ibu_hist = ob['ibu_phis'][itnum]*corrs
    ax0.plot(ob['midbins_mc'], ibu_hist, **ibu_style, label='IBU ' + ob['symbol'])

    # Plot the Ratios of the OmniFold and IBU distributions to truth (with statistical uncertainties)
    ibu_ratio = ibu_hist[:len(hepdata)]/(aleph_thrust + 10**-50)
    of_ratio = of_histgen[:len(hepdata)]/(aleph_thrust + 10**-50)
    ax1.plot([np.min(ob['midbins_mc']), np.max(ob['midbins_mc'])], [1, 1], '--', color='green', lw=0.75)
    
    # ratio uncertainties
    aleph_unc_ratio = aleph_errs/(aleph_thrust + 10**-50)
    ibu_unc_ratio = ob['ibu_phi_unc'][:len(hepdata)]*corrs[:len(hepdata)]/(aleph_thrust + 10**-50)
    of_unc_ratio = of_histgen_unc[:len(hepdata)]/(aleph_thrust + 10**-50)
    
    # data ratio
    ax1.errorbar(aleph_midbins, ob['data_hist'][:len(hepdata)]/(aleph_thrust + 10**-50), 
                 xerr=ob['binwidth_mc']/2,
                 color='black', **modplot.style('errorbar'))
    
    ax1.errorbar(aleph_midbins, ob['genobs_hist'][:len(hepdata)]/(aleph_thrust + 10**-50), 
                 xerr=ob['binwidth_mc']/2,
                 color='blue', **modplot.style('errorbar'))
    
    ax1.fill_between(aleph_midbins, 1 - aleph_unc_ratio, 1 + aleph_unc_ratio, 
                     facecolor=truth_style['facecolor'], zorder=-2)
    ax1.errorbar(aleph_midbins, ibu_ratio, xerr=ob['binwidth_mc']/2, yerr=ibu_unc_ratio, 
                                              color=ibu_style['color'], **modplot.style('errorbar'))
    ax1.errorbar(aleph_midbins, of_ratio, xerr=ob['binwidth_mc']/2, yerr=of_unc_ratio, 
                                              color=omnifold_style['color'], **modplot.style('errorbar'))

    # legend style and ordering
    loc, ncol = ob.get('legend_loc', 'upper right'), ob.get('legend_ncol', 2)
    order = [3, 4, 0, 5, 2, 1] # [2, 3, 0, 1, 4]#
    modplot.legend(ax=ax0, frameon=False, order=order, loc=loc, ncol=ncol)

    # stamp to put on the plots
    modplot.stamp(*ob['stamp_xy'], delta_y=0.06, ax=ax0,
                  line_0=r'\textbf{ALEPH Open Data}',
                  line_1=r'MC: \textsc{Pythia 6}',
                  line_2=r'$e^+e^-\,\sqrt{s}=91$ GeV',
                  line_3='Hadronic Events')

    # save plot (by default in the same directory as this notebook).
    # If running on binder, the plot can be accessed by first going to the jupyter file browser
    # (which itself can be accessed by copying the URL of this notebook and removing the name of the notebook
    # after the final "/"), selecting the square next to the name of the plot, and clicking "Download".
    #fig.savefig('UniFold_{}_NoCuts_tgBeforeCorrs.pdf'.format(obkey), bbox_inches='tight')
    path = os.path.join(os.getcwd(),'ThrustStudies')
    figname = 'UniFold_{}_NoCuts_tgBeforeCorrs.pdf'.format(obkey)
    #fig.savefig(os.path.join(path,figname), bbox_inches='tight')
    modplot.save(fig, figname, add_watermark=True, tx=221.5, ty=251.5, plots_dir='.')
    
    plt.show()
